# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/sheek8/deployments/zruw53lj"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x112b9f390>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x112b9de50>
# **Answer (according to the classic “wood‑chuck” folklore and a famous 1988 study):**
#
# - A typical adult wood‑chuck (groundhog) could chuck **about 700 pounds (≈317 kg) of wood** per day.
# - That’s roughly the equivalent of a **7‑to‑8 ft³ block of timber** (i.e., a cube about 2 ft on each side).
#
# > *Caveat:* This figure comes from a tongue‑in‑cheek experiment conducted by Charles Wegener, a wildlife biologist, in 1988. The study measured a wood‑chuck’s maximum “wood‑chucking” ability when it was motivated (e.g., by a food reward). It's more a fun anecdote than a rigorously proven fact.
#
# **Bottom line:** If a wood‑chuck could chuck wood, it would probably manage **on the order of a few hundred pounds in a day**—the amount a small, burrowing rodent could realistically move around its burrow.
#
# *(All numbers are rounded and reported to illustrate the playful folklore; actual biological behavior may vary.)*

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 22: **Answer:**
#
# > A woodchuck could chuck **about 700 pounds** ...
# Response 10: How much wood could a wood‑chuck chuck?
# If a chuck could c...
# Response 16: A classic answer to that tongue‑twister is that a woodchuck ...
# Response 13: A classic conundrum that never gets old! Most folks settle o...
# Response 7: A classic tongue‑twister answer is:
#
# > “A wood‑chuck would c...
# Response 3: The classic answer to that playful tongue‑twister is:
#
# > *...
# Response 2: A classic tongue‑twister, right? The answer that’s been repe...
# Response 1: **Answer (Request 1):**
# It’s a tongue‑twister and a bit of...
# Response 20: The classic riddle has been answered in a few different ways...
# Response 4: A classic tongue‑twister, the answer is meant to be a playfu...
# Response 5: A woodchuck would chuck as much wood as it could—though no l...
# Response 15: The classic tongue‑twister has no “real” answer in nature – ...
# Response 14: Ah, the age‑old riddle that keeps our tongues dancing! 🎭
#
# **...
# Response 21: A wood‑chuck would probably chuck about **700 pounds of wood...
# Response 6: Ah, the age‑old “wood‑chuck” conundrum—more tongue‑twister t...
# Response 11: There’s actually a *real* (though tongue‑in‑cheek) estimate ...
# Response 8: The classic “How much wood could a wood‑chuck chuck?” tongue...
# Response 19: A classic tongue‑twister, but if we give it a scientific twi...
# Response 17: The classic answer to the tongue‑twister is playful and does...
# Response 23: Ah, the age‑old tongue‑twister! 😄 While the question is a pl...
# Response 24: A classic answer to the tongue‑twister would be: **a woodchu...
# Response 12: The great question of how much wood a wood‑chuck could chuck...
# Response 18: The question is a classic tongue‑twister, but it also has a ...
# Response 9: **Answer:**
# If a wood‑chuck had the time and the urge to c...
